# %%
import networkx as nx
import os
import random

# Asegura que las carpetas necesarias existen
def crear_estructura_directorios():
    base = "ARCHIVOS_REDES"
    subdirs = ["ER", "WS", "ER_parametros", "WS_parametros"]
    for sub in subdirs:
        os.makedirs(os.path.join(base, sub), exist_ok=True)

crear_estructura_directorios()

def contar_archivos_en_directorio(directorio):
    return len([f for f in os.listdir(directorio) if f.endswith(".txt")])


def guardar_lista_adyacencia(grafo, nombre_base, modelo, parametros):
    """
    Guarda el grafo en formato lista de adyacencia y los parámetros usados.

    Args:
        grafo (nx.Graph): Grafo a guardar.
        nombre_base (str): Nombre base para el archivo.
        modelo (str): 'ER' o 'WS'.
        parametros (dict): Parámetros a guardar en el archivo de parámetros.
    """
    carpeta_grafos = os.path.join("ARCHIVOS_REDES", modelo)
    carpeta_params = os.path.join("ARCHIVOS_REDES", f"{modelo}_parametros")

    i = contar_archivos_en_directorio(carpeta_grafos)
    nombre_grafo = f"{nombre_base}_{i}.txt"
    nombre_param = f"{nombre_base}_{i}.txt"

    # Guardar lista de adyacencia
    with open(os.path.join(carpeta_grafos, nombre_grafo), 'w') as f:
        for nodo in sorted(grafo.nodes()):
            vecinos = sorted(grafo.neighbors(nodo))
            for vecino in vecinos:
                f.write(f"{nodo} {vecino}\n")

    # Guardar parámetros
    with open(os.path.join(carpeta_params, nombre_param), 'w') as f:
        for clave, valor in parametros.items():
            f.write(f"{clave}: {valor}\n")


def generar_red_ER_conexa(N, k_prom, aceptancia_N, aceptancia_k, nombre_base="ER"):
    p = k_prom / (N - 1)

    while True:
        G = nx.erdos_renyi_graph(N, p)
        if not nx.is_connected(G):
            giant = max(nx.connected_components(G), key=len)
            G = G.subgraph(giant).copy()

        N_real = G.number_of_nodes()
        k_real = sum(dict(G.degree()).values()) / N_real

        if (abs(N_real - N) / N * 100 <= aceptancia_N and
                abs(k_real - k_prom) / k_prom * 100 <= aceptancia_k):
            parametros = {
                "N_ideal": N,
                "N_real": N_real,
                "k_prom_ideal": k_prom,
                "k_prom_real": round(k_real, 3)
            }
            guardar_lista_adyacencia(G, nombre_base, "ER", parametros)
            return G, N_real, k_real


def generar_red_WS(N, k, p, nombre_base="WS"):
    G = nx.watts_strogatz_graph(N, k, 0)
    feos = []
    guapos = []

    for edge in G.edges():
        if random.random() < p:
            feos.append(edge)
        else:
            guapos.append(edge)

    while feos:
        random.shuffle(feos)
        enlace0 = feos[0]
        nodo0_a, nodo0_b = enlace0
        encontrado = False

        for i in range(1, len(feos)):
            enlace1 = feos[i]
            nodo1_a, nodo1_b = enlace1
            if nodo0_a not in enlace1 and nodo0_b not in enlace1:
                nodos1 = [nodo1_a, nodo1_b]
                random.shuffle(nodos1)
                A = (nodo0_a, nodos1[0])
                B = (nodo0_b, nodos1[1])
                if A not in guapos and (A[1], A[0]) not in guapos and B not in guapos and (B[1], B[0]) not in guapos:
                    guapos.append(A)
                    guapos.append(B)
                    del feos[i]
                    del feos[0]
                    encontrado = True
                    break

        if not encontrado:
            guapos.append(feos[0])
            del feos[0]

    G_guapo = nx.Graph()
    G_guapo.add_nodes_from(range(N))
    G_guapo.add_edges_from(guapos)

    parametros = {
        "N": N,
        "k": k,
        "p": p
    }

    guardar_lista_adyacencia(G_guapo, nombre_base, "WS", parametros)
    return G_guapo

# %%
from datetime import datetime

def escribir_en_historial(nombre_archivo, parametros, archivo_inicio, archivo_fin, detalles_redes=[]):
    ruta = os.path.join("ARCHIVOS_REDES", nombre_archivo)
    with open(ruta, 'a', encoding='utf-8') as f:
        f.write("---------------------------------------------------------------------------------\n")
        f.write(f"Fecha de ejecución: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write("Parámetros:\n")
        for clave, valor in parametros.items():
            f.write(f"{clave}: {valor}\n")
        f.write(f"Archivo inicial generado: {archivo_inicio}\n")
        f.write(f"Archivo final generado: {archivo_fin}\n")

        if detalles_redes:
            f.write("\nDetalles de las redes generadas:\n")
            for i, (nombre_archivo, N_real, k_real) in enumerate(detalles_redes):
                f.write(f"{i+1}. {nombre_archivo} -> N_real: {N_real}, k_real: {round(k_real, 3)}\n")

        f.write("---------------------------------------------------------------------------------\n\n")
        
def generar_varias_redes_ER(N_redes, N_nodos, k_prom, aceptancia_N, aceptancia_k, nombre_base="ER"):
    carpeta_grafos = os.path.join("ARCHIVOS_REDES", "ER")
    i_inicial = contar_archivos_en_directorio(carpeta_grafos)

    for _ in range(N_redes):
        generar_red_ER_conexa(N_nodos, k_prom, aceptancia_N, aceptancia_k, nombre_base)

    i_final = i_inicial + N_redes - 1
    archivo_inicio = f"{nombre_base}_{i_inicial}.txt"
    archivo_fin = f"{nombre_base}_{i_final}.txt"

    parametros_historial = {
        "N_redes": N_redes,
        "N_nodos": N_nodos,
        "k_prom": k_prom,
        "aceptancia_N (%)": aceptancia_N,
        "aceptancia_k (%)": aceptancia_k
    }

    escribir_en_historial("Historial_ER.txt", parametros_historial, archivo_inicio, archivo_fin)
    with open("ARCHIVOS_REDES/Historial_WS.txt", 'r', encoding='latin1') as f:
        contenido = f.read()

    with open("ARCHIVOS_REDES/Historial_WS.txt", 'w', encoding='utf-8') as f:
        f.write(contenido)



def generar_varias_redes_WS(N_redes, N_nodos, k, p, nombre_base="WS"):
    carpeta_grafos = os.path.join("ARCHIVOS_REDES", "WS")
    i_inicial = contar_archivos_en_directorio(carpeta_grafos)

    for _ in range(N_redes):
        generar_red_WS(N_nodos, k, p, nombre_base)

    i_final = i_inicial + N_redes - 1
    archivo_inicio = f"{nombre_base}_{i_inicial}.txt"
    archivo_fin = f"{nombre_base}_{i_final}.txt"

    parametros_historial = {
        "N_redes": N_redes,
        "N_nodos": N_nodos,
        "k": k,
        "p": p
    }

    escribir_en_historial("Historial_WS.txt", parametros_historial, archivo_inicio, archivo_fin)
    with open("ARCHIVOS_REDES/Historial_WS.txt", 'r', encoding='latin1') as f:
        contenido = f.read()
    with open("ARCHIVOS_REDES/Historial_WS.txt", 'w', encoding='utf-8') as f:
        f.write(contenido)

# %%
## SOLO TOCAR LOS PARÁMETROS DESDE AQUÍ

N_redes=1000
N_nodos=1000
k=4
p=0.3
generar_varias_redes_WS(N_redes, N_nodos, k, p)

# %%
## SOLO TOCAR LOS PARÁMETROS DESDE AQUÍ
N_redes=100
N_nodos=10
k_prom=5
aceptancia_N=5 ## Nunca superar 5
aceptancia_k=3 #Nunca superar 5

generar_varias_redes_ER(N_redes, N_nodos, k_prom, aceptancia_N, aceptancia_k)

# %%
# !git add .
# Out:
# warning: in the working copy of '.ipynb_checkpoints/CODIGO_REDES-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'CODIGO_REDES.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "Añadido codigo, estructura de carpetas y funciones para guardar redes"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'USUARIO@LAPTOP-IN0RIPLH.(none)')

# %%
# !git config --global user.name "DonIgnacioHerraiz"
# !git config --global user.email "874462@unizar.es"

# %%
# !git config --list
# Out:
# diff.astextplain.textconv=astextplain
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# http.sslbackend=openssl
# http.sslcainfo=C:/Program Files/Git/mingw64/etc/ssl/certs/ca-bundle.crt
# core.autocrlf=true
# core.fscache=true
# core.symlinks=false
# pull.rebase=false
# credential.helper=manager
# credential.https://dev.azure.com.usehttppath=true
# init.defaultbranch=main
# core.editor="C:\Users\USUARIO\Desktop\Segundo semeste 2324\Computacional\Microsoft VS Code\bin\code" --wait
# user.name=DonIgnacioHerraiz
# user.email=874462@unizar.es
# core.repositoryformatversion=0
# core.filemode=false
# core.bare=false
# core.logallrefupdates=true
# core.symlinks=false
# core.ignorecase=true
# remote.origin.url=https://github.com/872943/CaOtIcOs.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.remote=origin
# branch.main.merge=refs/heads/main

# %%
# !git commit -m "Primer commit con redes y estructura"
# Out:
# [main af19946] Primer commit con redes y estructura
#  122 files changed, 320310 insertions(+)
#  create mode 100644 .ipynb_checkpoints/CODIGO_REDES-checkpoint.ipynb
#  create mode 100644 ARCHIVOS_REDES/ER/ER_0.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_1.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_10.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_11.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_12.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_13.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_14.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_15.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_16.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_17.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_18.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_19.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_2.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_20.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_21.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_22.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_23.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_24.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_25.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_26.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_27.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_28.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_29.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_3.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_30.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_31.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_32.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_33.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_34.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_35.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_36.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_37.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_38.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_39.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_4.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_5.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_6.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_7.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_8.txt
#  create mode 100644 ARCHIVOS_REDES/ER/ER_9.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_0.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_1.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_10.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_11.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_12.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_13.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_14.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_15.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_16.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_17.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_18.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_19.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_2.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_20.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_21.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_22.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_23.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_24.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_25.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_26.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_27.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_28.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_29.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_3.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_30.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_31.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_32.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_33.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_34.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_35.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_36.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_37.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_38.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_39.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_4.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_5.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_6.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_7.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_8.txt
#  create mode 100644 ARCHIVOS_REDES/ER_parametros/ER_9.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_0.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_1.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_10.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_11.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_12.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_13.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_14.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_15.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_16.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_17.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_18.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_19.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_2.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_3.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_4.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_5.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_6.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_7.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_8.txt
#  create mode 100644 ARCHIVOS_REDES/WS/WS_9.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_0.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_1.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_10.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_11.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_12.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_13.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_14.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_15.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_16.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_17.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_18.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_19.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_2.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_3.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_4.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_5.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_6.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_7.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_8.txt
#  create mode 100644 ARCHIVOS_REDES/WS_parametros/WS_9.txt
#  create mode 100644 CODIGO_REDES.ipynb

# %%
# !git push
# Out:
# To https://github.com/872943/CaOtIcOs.git
#    d56cfae..af19946  main -> main
